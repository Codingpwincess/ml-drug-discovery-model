# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Enoyl-reductase (Tuberculosis)**

# %%
# Target search for tuberculosis (inhA)
target = new_client.target
target_query = target.search('reductase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references                    organism  \
# 0                 []                Homo sapiens
# 1                 []                Homo sapiens
# 2                 []  Mycobacterium tuberculosis
# 3                 []                Homo sapiens
# 4                 []                Homo sapiens
# ..               ...                         ...
# 826               []                Homo sapiens
# 827               []                Homo sapiens
# 828               []                Homo sapiens
# 829               []                Homo sapiens
# 830               []                Homo sapiens
#
#                                          pref_name  score  species_group_flag  \
# 0                   7-dehydrocholesterol reductase   11.0               False
# 1    Ribonucleoside-diphosphate reductase M1 chain   10.0               False
# 2           Enoyl-[acyl-carrier-protein] reductase   10.0               False
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Mtb Enoyl-[acyl-carrier-protein] reductase* (third entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Mtb Enoyl-[acyl-carrier-protein] reductase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL1849'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Mtb Enoyl-[acyl-carrier-protein] reductase* (CHEMBL1849) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 452                                               None             None
# 453  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 454                                               None             None
# 455  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 456  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Enoyl-[acyl-carrier-protein] reductase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipython-input-9-3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 452                                               None             None
# 453  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 454                                               None             None
# 455  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 373

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 452                                               None             None
# 453  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 454                                               None             None
# 455  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 456  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL217926                O=C(Nc1ccccc1)C1CC(=O)N(C2CCCCC2)C1
# 1         CHEMBL216547              O=C(Nc1ccccc1Br)C1CC(=O)N(C2CCCCC2)C1
# 2         CHEMBL213720        O=C(Nc1ccc2c(c1)OCCO2)C1CC(=O)N(C2CCCCC2)C1
# 3         CHEMBL217274            Cc1cccc(C)c1NC(=O)C1CC(=O)N(C2CCCCC2)C1
# 4         CHEMBL217773     O=C(Nc1ccc(Oc2ccccc2)cc1)C1CC(=O)N(C2CCCCC2)C1
# ..                 ...                                                ...
# 452      CHEMBL5398235  Cc1cc(Nc2ccc(N3CCC(c4ccccc4)CC3)cc2)c2cc(Br)cc...
# 453      CHEMBL5430244           Cc1cc(Nc2ccc(-n3cccn3)cc2)c2cc(Br)ccc2n1
# 454      CHEMBL5434416          Cc1cc(Nc2ccc(N3CCCC3CO)cc2)c2cc(Br)ccc2n1
# 455      CHEMBL5406599          CCc1cc(Nc2ccc(N3CCCCC3)cc2)c2cc(Br)ccc2n1
# 456      CHEMBL5399436          CCc1cc(Nc2ccc(N3CCCCC3)cc2)c2cc(Cl)ccc2n1
#
#     standard_value
# 0          10660.0
# 1         100000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Enoyl-[acyl-carrier-protein] reductase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Enoyl-[acyl-carrier-protein] reductase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL217926                O=C(Nc1ccccc1)C1CC(=O)N(C2CCCCC2)C1
# 1         CHEMBL216547              O=C(Nc1ccccc1Br)C1CC(=O)N(C2CCCCC2)C1
# 2         CHEMBL213720        O=C(Nc1ccc2c(c1)OCCO2)C1CC(=O)N(C2CCCCC2)C1
# 3         CHEMBL217274            Cc1cccc(C)c1NC(=O)C1CC(=O)N(C2CCCCC2)C1
# 4         CHEMBL217773     O=C(Nc1ccc(Oc2ccccc2)cc1)C1CC(=O)N(C2CCCCC2)C1
# ..                 ...                                                ...
# 368      CHEMBL5398235  Cc1cc(Nc2ccc(N3CCC(c4ccccc4)CC3)cc2)c2cc(Br)cc...
# 369      CHEMBL5430244           Cc1cc(Nc2ccc(-n3cccn3)cc2)c2cc(Br)ccc2n1
# 370      CHEMBL5434416          Cc1cc(Nc2ccc(N3CCCC3CO)cc2)c2cc(Br)ccc2n1
# 371      CHEMBL5406599          CCc1cc(Nc2ccc(N3CCCCC3)cc2)c2cc(Br)ccc2n1
# 372      CHEMBL5399436          CCc1cc(Nc2ccc(N3CCCCC3)cc2)c2cc(Cl)ccc2n1
#
#      standard_value         class
# 0           10660.0      inactive
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Enoyl-[acyl-carrier-protein] reductase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip enoyl-reductase.zip *.csv
# Out:
#   adding: Enoyl-[acyl-carrier-protein] reductase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: Enoyl-[acyl-carrier-protein] reductase_02_bioactivity_data_preprocessed.csv (deflated 80%)
#   adding: Enoyl-[acyl-carrier-protein] reductase_03_bioactivity_data_curated.csv (deflated 81%)

# %%
! ls -l
# Out:
# total 364
# -rw-r--r-- 1 root root 266492 Jul  6 14:43 'Enoyl-[acyl-carrier-protein] reductase_01_bioactivity_data_raw.csv'
# -rw-r--r-- 1 root root  26831 Jul  6 14:45 'Enoyl-[acyl-carrier-protein] reductase_02_bioactivity_data_preprocessed.csv'
# -rw-r--r-- 1 root root  30390 Jul  6 14:48 'Enoyl-[acyl-carrier-protein] reductase_03_bioactivity_data_curated.csv'
# -rw-r--r-- 1 root root  35114 Jul  6 14:49  enoyl-reductase.zip
# drwxr-xr-x 1 root root   4096 Jul  1 21:04  sample_data

# %% [markdown]
# ---
